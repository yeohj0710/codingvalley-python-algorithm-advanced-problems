# %% [markdown]
# [5번 문제] 힙에서 최솟값을 제거하고 정렬하는 작업이 이루어지는 과정을 알맞게 나열한 것은? (2)
#
# ㉠ 최솟값에 해당하는 루트 노드를 제거합니다.
#
# ㉡ 힙의 특성이 유지될 때까지 자식 노드와의 위치 교환을 반복합니다.
#
# ㉢ 가장 아래층 맨 오른쪽에 있는 노드를 루트 노드가 있던 자리로 이동합니다.
#
# ① ㉠ - ㉡ - ㉢
#
# ② ㉠ - ㉢ - ㉡
#
# ③ ㉡ - ㉠ - ㉢
#
# ④ ㉢ - ㉠ - ㉡
