# %% [markdown]
# [4번 문제] 힙에서 새로운 노드를 추가하고 정렬하는 작업이 이루어지는 과정을 알맞게 나열한 것은? (3)
#
# ㉠ 새로 추가한 노드가 부모 노드보다 작으면 두 노드를 교환합니다.
#
# ㉡ 힙의 특성이 유지될 때까지 부모 노드와의 위치 교환을 반복합니다.
#
# ㉢ 새 노드를 가장 아래층의 맨 오른쪽에 추가합니다.
#
# ① ㉠ - ㉢ - ㉡
#
# ② ㉡ - ㉢ - ㉠
#
# ③ ㉢ - ㉠ - ㉡
#
# ④ ㉢ - ㉡ - ㉠
