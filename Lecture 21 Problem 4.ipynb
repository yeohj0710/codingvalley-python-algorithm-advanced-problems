# %% [markdown]
# [4번 문제] 그림은 다익스트라 알고리즘에서 1번 노드에 방문하고 인접 노드들의 거리를 갱신한 직후의 과정까지를 나타낸 것이다. 다음으로 방문할 노드의 번호와 거리가 갱신되는 노드의 번호를 순서대로 나타낸 것은? (4)

# %%
from IPython.display import Image
Image(filename="./images/Lecture 21 Problem 4.png")

# %% [markdown]
# ① 다음으로 방문할 노드: 2번 / 거리가 갱신되는 노드: 4번
#
# ② 다음으로 방문할 노드: 3번 / 거리가 갱신되는 노드: 4번
#
# ③ 다음으로 방문할 노드: 4번 / 거리가 갱신되는 노드: 1번
#
# ④ 다음으로 방문할 노드: 4번 / 거리가 갱신되는 노드: 2번, 3번
