# %% [markdown]
# [4번 문제] 다음 중 자료구조에서 수행되는 각 작업의 시간 복잡도로 가장 적절한 것은? (3)
#
# ① 연결 리스트에서 중간에 위치한 데이터의 인덱스가 주어질 때 데이터에 접근하는 작업: O(1)
#
# ② 리스트에서 중간에 위치한 데이터의 인덱스가 주어질 때 데이터에 접근하는 작업: O(n)
#
# ③ 연결 리스트에서 삭제할 데이터를 O(n) 시간에 찾은 후, 연결을 끊어내는 작업: O(1)
#
# ④ 리스트에서 삭제할 데이터를 O(n) 시간에 찾은 후, 뒤에 있는 데이터를 한 개씩 당겨오는 작업: O(1)
