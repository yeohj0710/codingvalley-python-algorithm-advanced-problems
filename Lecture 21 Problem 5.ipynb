# %% [markdown]
# [5번 문제] 다익스트라 알고리즘의 구현 방법으로 적절하지 않은 것은? (2)
#
# ① 가중치를 가지는 그래프는 인접 리스트의 형태로 저장할 수 있다.
#
# ② 딕셔너리를 이용해 각 노드까지의 최단 거리와 노드 번호를 각각 key와 value로 저장할 수 있다.
#
# ③ 우선순위 큐를 이용해 방문하지 않은 노드 중 출발 노드에서 가장 가까운 노드를 효율적으로 찾을 수 있다.
#
# ④ 우선순위 큐에 노드 데이터를 추가하고 삭제하는 과정에는 heapq 모듈의 함수들을 활용할 수 있다.
