# %% [markdown]
# [예비] 다음과 같은 상황에서 사용해야 하는 자료구조로 가장 적절한 것은? (4)
#
# - 데이터를 일렬로 관리해야 합니다.
# - 데이터를 맨 앞에 추가해야 하는 작업이 많습니다.
# - 중간에 데이터를 추가하거나 중간에 위치한 데이터를 삭제해야 하는 작업이 많습니다.
# - 전체 데이터를 앞에서부터 순서대로 확인해야 하는 작업이 많습니다.
#
# ① 리스트
#
# ② 스택
#
# ③ 덱
#
# ④ 연결 리스트
