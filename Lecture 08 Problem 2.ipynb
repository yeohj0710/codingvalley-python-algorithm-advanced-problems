# %% [markdown]
# [2번 문제] 단순 연결 리스트의 노드에 대한 설명으로 적절하지 않은 것은? (3)
#
# ① 노드는 연결 리스트를 구성하는 기본 단위이다.
#
# ② 노드에는 데이터와, 다음 노드의 주소가 저장되어 있다.
#
# ③ 첫 번째 노드는 head라고 부르며, 별도의 변수로 저장해 주지 않아도 된다.
#
# ④ 마지막 노드는 다음 노드의 주소가 없으므로 None 값을 가진다.
