# %% [markdown]
# [1번 문제] 연결 리스트에 대한 설명으로 가장 적절한 것은? (4)
#
# ① 먼저 들어온 데이터가 먼저 빠져나가는 방식으로 처리되는 자료구조이다.
#
# ② 나중에 들어온 데이터가 먼저 빠져나가는 방식으로 처리되는 자료구조이다.
#
# ③ 데이터가 연속적인 메모리 공간에 순차적으로 저장되는 자료구조이다.
#
# ④ 각 데이터가 다음 데이터를 가리키며 일렬로 연결된 자료구조이다.
